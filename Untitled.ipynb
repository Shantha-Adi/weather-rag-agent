# %%
# !streamlit run app.py
# Out:
# 'streamlit' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -angchain (c:\users\shantha adi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -angchain (c:\users\shantha adi\appdata\roaming\python\python39\site-packages)
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\Shantha Adi\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Shantha Adi\AppData\Roaming\Python\Python39\site-packages\~~mpy'.
#   You can safely remove it manually.
#   WARNING: The script streamlit.exe is installed in 'C:\Users\Shantha Adi\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
# ...
